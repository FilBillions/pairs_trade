# %%
from coint_backtest import CointegrationBacktest

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='backtest_output/backtest_results_COP_ET_method_1_cash.csv'

# %%
return_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 210
# --------------------------------------------------
# 90% Confidence Interval: (-0.2824, 0.2901)
# 95% Confidence Interval: (-0.3373, 0.3449)
# 98% Confidence Interval: (-0.401, 0.4087)
# 99% Confidence Interval: (-0.401, 0.4087)
# --------------------------------------------------
# Model Results:
# Model Mean: 0.0%
# Model Std: 2.52%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 10.34%
# SPY Buy/Hold Std: 15.92%
# --------------------------------------------------

# %%
sharpe_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 210
# --------------------------------------------------
# 90% Confidence Interval: (-0.1104, -0.007)
# 95% Confidence Interval: (-0.1203, 0.0029)
# 98% Confidence Interval: (-0.1318, 0.0145)
# 99% Confidence Interval: (-0.1318, 0.0145)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: -0.0587
# Model Std: 0.4555
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.874
# SPY Std: 0.9006
# --------------------------------------------------
